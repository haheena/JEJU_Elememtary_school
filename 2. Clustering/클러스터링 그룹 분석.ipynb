# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('K-means_최종결과_0506.csv')

# %%
data
# Out:
#             학교명  규제표지  보조표지  주의표지  지시표지       차로수  신호등개수        도로폭    보차분리비율  \
# 0        곽금초등학교     6    13     5     7  3.142857     25  11.000000  1.000000
# 1        광령초등학교     2    13     8     4  2.000000      1  14.000000  1.000000
# 2        구엄초등학교     3    15     4     3  3.125000     23  17.844298  0.000000
# 3        귀덕초등학교     1     8     3     5  3.142857      4  17.946266  0.000000
# 4        금악초등학교     5     9    16    19  2.000000      2  10.000000  0.000000
# 5        남광초등학교    23    33     3    14  2.093750     22  12.000000  1.000000
# 6        남원초등학교     5    19    13     0  2.000000      6  11.420351  1.000000
# 7        납읍초등학교     2    19     4     0  2.273525      3  12.812500  1.000000
# 8        노형초등학교    24    28    10     9  3.153846     21   8.000000  1.000000
# 9        대흘초등학교     0     5     7     2  2.000000      1  11.420351  1.000000
# 10       더럭초등학교     8    22     5    16  2.923077     15  10.000000  0.000000
# ...

# %%
data.groupby('cluster_label_scaled_pca').mean()
# Out:
#                                규제표지       보조표지       주의표지       지시표지  \
# cluster_label_scaled_pca
# 0                         10.500000  20.571429  12.428571   9.000000
# 1                         11.142857  21.071429   7.000000  10.571429
# 2                          2.380952  10.142857   4.714286   3.000000
#
#                                차로수      신호등개수        도로폭    보차분리비율     안전도지수
# cluster_label_scaled_pca
# 0                         1.743112   2.642857  11.548672  0.779762  0.024917
# 1                         3.112525  20.142857  15.819426  0.821429  0.022321
# 2                         1.992896   2.571429  12.465493  0.753968  0.006112

# %%
data.groupby('cluster_label_scaled_pca').sum()
# Out:
#                           규제표지  보조표지  주의표지  지시표지        차로수  신호등개수  \
# cluster_label_scaled_pca
# 0                          147   288   174   126  24.403571     37
# 1                          156   295    98   148  43.575349    282
# 2                           50   213    99    63  41.850806     54
#
#                                  도로폭     보차분리비율     안전도지수
# cluster_label_scaled_pca
# 0                         161.681403  10.916667  0.348844
# 1                         221.471967  11.500000  0.312495
# 2                         261.775344  15.833333  0.128349

# %%
data.groupby('cluster_label_scaled_pca').median()
# Out:
#                           규제표지  보조표지  주의표지  지시표지       차로수  신호등개수        도로폭  \
# cluster_label_scaled_pca
# 0                          8.5  21.0   9.5  10.0  2.000000    3.0  11.420351
# 1                          9.5  22.0   5.5   9.0  3.133929   20.5  14.500000
# 2                          2.0  11.0   5.0   2.0  2.000000    3.0  12.812500
#
#                           보차분리비율     안전도지수
# cluster_label_scaled_pca
# 0                            1.0  0.012600
# 1                            1.0  0.014411
# 2                            1.0  0.004588

# %%
data.groupby('cluster_label_scaled_pca').var()
# Out:
#                                규제표지       보조표지       주의표지       지시표지  \
# cluster_label_scaled_pca
# 0                         49.807692  67.186813  73.186813  38.923077
# 1                         57.208791  60.840659  22.000000  43.648352
# 2                          4.247619  28.528571   9.114286   8.100000
#
#                                차로수      신호등개수        도로폭    보차분리비율     안전도지수
# cluster_label_scaled_pca
# 0                         0.176594   1.631868   8.345555  0.153426  0.000792
# 1                         0.334410  72.439560  36.486407  0.138736  0.000262
# 2                         0.215181   2.557143   9.959703  0.160053  0.000037
