# %%
import pandas as pd

# %%
data=pd.read_csv('traindata.csv')
data.head()
# Out:
#    사고 발생 건수  행정동      기간  강수일수  안개일수  눈일수  강수량(mm)   가중교통량   신호기       유동인구  \
# 0         3  건입동  201801    18     0   12     58.0  860.73  15.0  341251.68
# 1         6  건입동  201802    11     0    8     86.6  860.73  15.0  342506.89
# 2         7  건입동  201803    10     2    0    118.0  860.73  15.0  327685.10
# 3         2  건입동  201804     8     0    1    112.5  860.73  15.0  333694.03
# 4         6  건입동  201805    12     4    0     98.8  860.73  15.0  333584.71
#
#      면적
# 0  2.53
# 1  2.53
# 2  2.53
# 3  2.53
# 4  2.53

# %%
data['weather'] = data['강수일수']+data['안개일수']+data['눈일수']

# %%
data.head()
# Out:
#    사고 발생 건수  행정동      기간  강수일수  안개일수  눈일수  강수량(mm)   가중교통량   신호기       유동인구  \
# 0         3  건입동  201801    18     0   12     58.0  860.73  15.0  341251.68
# 1         6  건입동  201802    11     0    8     86.6  860.73  15.0  342506.89
# 2         7  건입동  201803    10     2    0    118.0  860.73  15.0  327685.10
# 3         2  건입동  201804     8     0    1    112.5  860.73  15.0  333694.03
# 4         6  건입동  201805    12     4    0     98.8  860.73  15.0  333584.71
#
#      면적  weather
# 0  2.53       30
# 1  2.53       19
# 2  2.53       12
# 3  2.53        9
# 4  2.53       16

# %%
import matplotlib as mpl

print(mpl.matplotlib_fname())
print(mpl.get_cachedir())
plt.rcParams['font.family'] = 'NanumGothic'

import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 10))

corr = data.corr()  # 상관계수 행렬 구하기
sns.heatmap(corr, annot=True, fmt='.2f',cmap='coolwarm')
plt.title('상관관계 히트맵')
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\matplotlib\mpl-data\matplotlibrc
# C:\Users\user\.matplotlib
# C:\Users\user\anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
