# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\seses\\Downloads\\traindata.csv")

# %%
#행정동별 유동인구

plt.figure(figsize=(20, 10))
tips = sns.load_dataset('tips')
sns.set_palette('Dark2')



# legend, title등 font 속성

fontdict={'fontname': 'NanumSquare',
     'fontsize': 25,
     'style': 'oblique', # 'oblique'
      'fontweight': 'bold'}  # 'heavy', 'light', 'ultrabold', 'ultralight'
# x,y axis 폰트 속성 설정

plt.rcParams['font.family'] = 'NanumSquare'

plt.rcParams['font.size'] = 15 # 개별적용 - plt.yticks(fontsize=20)

plt.rcParams['font.weight'] = 'bold'

# 막대그래프 그리기
sns.barplot(df_fin_mean['행정동'], df_fin_mean['유동인구'],data=tips)

# 그래프 제목, x축 제목, y축 제목 설정
plt.title('행정동별 유동인구',**fontdict)
plt.xticks(rotation=45)
plt.xlabel('행정동명',**fontdict)
plt.ylabel('유동인구',**fontdict)

# 그래프 출력
#plt.show()
plt.savefig("C:\\Users\\seses\\Downloads\\0427_eda\\행정동별유동인구.png",facecolor='#ffffff')
# Out:
# C:\Users\seses\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df_fin_mean=df_fin_mean.sort_values('면적', ascending=False)

# %%
#행정동별 면적
plt.figure(figsize=(20, 10))
tips = sns.load_dataset('tips')
sns.set_palette('Dark2')



# legend, title등 font 속성

fontdict={'fontname': 'NanumSquare',
     'fontsize': 25,
     'style': 'oblique', # 'oblique'
      'fontweight': 'bold'}  # 'heavy', 'light', 'ultrabold', 'ultralight'
# x,y axis 폰트 속성 설정

plt.rcParams['font.family'] = 'NanumSquare'

plt.rcParams['font.size'] = 15 # 개별적용 - plt.yticks(fontsize=20)

plt.rcParams['font.weight'] = 'bold'

# 막대그래프 그리기
sns.barplot(df_fin_mean['행정동'], df_fin_mean['면적'],data=tips)

# 그래프 제목, x축 제목, y축 제목 설정
plt.title('행정동별 면적',**fontdict)
plt.xticks(rotation=45)
plt.xlabel('행정동명',**fontdict)
plt.ylabel('면적',**fontdict)

# 그래프 출력
#plt.show()
plt.savefig("C:\\Users\\seses\\Downloads\\0427_eda\\행정동별면적.png",facecolor='#ffffff')
# Out:
# C:\Users\seses\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df_fin_mean=df_fin_mean.reset_index()
df_fin_mean=df_fin_mean[['행정동','유동인구']]
df = df.drop(df[df['행정동'] == '추자면'].index)
df_concat = pd.concat([df, df_fin_mean], axis=0)
merged_df = pd.concat([df, df_fin_mean], axis=0, ignore_index=True)
merged_df = pd.merge(df, df_fin_mean, on='행정동')

# %%
merged_df
# Out:
#      행정동      면적          유동인구
# 0    한림읍   91.09  2.133418e+07
# 1    애월읍  202.16  4.107650e+07
# 2    구좌읍  185.93  1.528785e+07
# 3    조천읍  150.64  2.330201e+07
# 4    한경면   79.03  7.318966e+06
# 5    우도면    6.18  1.759750e+06
# 6   일도1동    0.33  2.954856e+06
# 7   일도2동    2.18  2.748899e+07
# 8   이도1동    0.69  1.211701e+07
# 9   이도2동    5.40  5.622553e+07
# 10  삼도1동    1.27  1.122664e+07
# 11  삼도2동    0.83  7.308031e+06
# 12  용담1동    0.61  7.529581e+06
# 13  용담2동    4.93  1.678874e+07
# 14   건입동    2.53  9.868491e+06
# 15   화북동    8.29  2.515250e+07
# 16   삼양동    9.53  1.903225e+07
# 17   봉개동   47.34  6.257204e+06
# 18   아라동   70.64  4.010666e+07
# 19   오라동   28.74  1.825561e+07
# 20    연동   12.32  4.892509e+07
# 21   노형동   45.24  5.468940e+07
# 22   외도동    8.40  1.158210e+07
# 23   이호동    2.56  4.578099e+06
# 24   도두동    4.03  3.360250e+06
# 25   대정읍   78.63  1.756753e+07
# 26   남원읍  188.51  1.512131e+07
# 27   성산읍  107.79  1.591081e+07
# 28   안덕면  105.60  1.852021e+07
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#사고건수 상위 다섯개 도로의 사고건수 그래프

plt.figure(figsize=(10, 6))
tips = sns.load_dataset('tips')
sns.set_palette('Dark2')



# legend, title등 font 속성

fontdict={'fontname': 'NanumSquare',
     'fontsize': 20,
     'style': 'oblique', # 'oblique'
      'fontweight': 'bold'}  # 'heavy', 'light', 'ultrabold', 'ultralight'
# x,y axis 폰트 속성 설정

plt.rcParams['font.family'] = 'NanumSquare'

plt.rcParams['font.size'] = 15 # 개별적용 - plt.yticks(fontsize=20)

plt.rcParams['font.weight'] = 'bold'

# 두 개의 선 그래프 그리기
plt.figure(figsize=(20, 6))
sns.lineplot(merged_df['행정동'], merged_df['유동인구'],data=tips)
sns.lineplot(merged_df['행정동'], merged_df['면적'],data=tips)
plt.ticklabel_format(axis='y',useOffset=False, style='plain')
# 그래프 제목, x축 제목, y축 제목 설정
plt.title('행정동별 유동인구와 면적 추이',**fontdict)
plt.xticks(rotation=45)
plt.xlabel('행정동',**fontdict)
plt.ylabel('Amount',**fontdict)

# 범례 추가
plt.legend(['유동인구', '면적'])

# 그래프 출력
plt.show()
#plt.savefig('C:\\Users\\seses\\Downloads\\eda_0426\\행정동별유동인구와총인구수추이.png',facecolor='#ffffff')
# Out:
# C:\Users\seses\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\seses\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
groups=df.groupby(['년','월','도로명','행정동'])
grouped=groups.sum()
grouped = grouped.reset_index()

# %%
#년월 행 만들기
for i in range(len(grouped['월'])):
    if len(str(grouped['월'][i])) == 1:
        grouped['년월'] = str(grouped['년'][i]) + '0' + str(grouped['월'][i])
    else:
        grouped['년월'] = str(grouped['년'][i]) + str(grouped['월'][i])
for i in range(len(grouped['월'])):
    if len(str(grouped['월'][i])) == 1:
        grouped['년월'][i] = str(grouped['년'][i]) + '0' + str(grouped['월'][i])
    else:
        grouped['년월'][i] = str(grouped['년'][i]) + str(grouped['월'][i])
# Out:
# C:\Users\seses\AppData\Local\Temp/ipykernel_30336/2585164961.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped['년월'][i] = str(grouped['년'][i]) + '0' + str(grouped['월'][i])
# C:\Users\seses\AppData\Local\Temp/ipykernel_30336/2585164961.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped['년월'][i] = str(grouped['년'][i]) + str(grouped['월'][i])

# %% [markdown]
# # 글꼴 적용

# %%
import matplotlib as mpl

print(mpl.matplotlib_fname())
print(mpl.get_cachedir())
# Out:
# C:\Users\seses\anaconda3\lib\site-packages\matplotlib\mpl-data\matplotlibrc
# C:\Users\seses\.matplotlib

# %%
#한글깨짐 해결
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'NanumSquare'

# %% [markdown]
# # 전체 변수 상관관계

# %%
import pandas as pd
import seaborn as sns
plt.figure(figsize=(10, 10))

corr = grouped.corr()  # 상관계수 행렬 구하기
sns.heatmap(corr, annot=True, fmt='.2f',cmap='coolwarm')
plt.title('상관관계 히트맵')
plt.show()

# %% [markdown]
# # 행정동별 강수량

# %%
grouped=grouped.groupby(['행정동'])
grouped=grouped.sum()
grouped=grouped.reset_index()
grouped=grouped.sort_values('강수량(mm)', ascending=False)

# %%
#행정동별 강수량

plt.figure(figsize=(20, 10))
tips = sns.load_dataset('tips')
sns.set_palette('Dark2')



# legend, title등 font 속성

fontdict={'fontname': 'NanumSquare',
     'fontsize': 25,
     'style': 'oblique', # 'oblique'
      'fontweight': 'bold'}  # 'heavy', 'light', 'ultrabold', 'ultralight'
# x,y axis 폰트 속성 설정

plt.rcParams['font.family'] = 'NanumSquare'

plt.rcParams['font.size'] = 15 # 개별적용 - plt.yticks(fontsize=20)

plt.rcParams['font.weight'] = 'bold'

# 막대그래프 그리기
sns.barplot(grouped['행정동'], grouped['강수량(mm)'],data=tips)

# 그래프 제목, x축 제목, y축 제목 설정
plt.title('행정동별 강수량',**fontdict)
plt.xticks(rotation=45)
plt.xlabel('행정동명',**fontdict)
plt.ylabel('강수량',**fontdict)

# 그래프 출력
#plt.show()
plt.savefig('C:\\Users\\seses\\Downloads\\eda_0426\\행정동별강수량.png',facecolor='#ffffff')
# Out:
# C:\Users\seses\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 행정동별 강수일수

# %%
grouped=grouped.sort_values('강수일수', ascending=False)

# %%
#행정동별 강수일수

plt.figure(figsize=(20, 10))
tips = sns.load_dataset('tips')
sns.set_palette('Dark2')



# legend, title등 font 속성

fontdict={'fontname': 'NanumSquare',
     'fontsize': 25,
     'style': 'oblique', # 'oblique'
      'fontweight': 'bold'}  # 'heavy', 'light', 'ultrabold', 'ultralight'
# x,y axis 폰트 속성 설정

plt.rcParams['font.family'] = 'NanumSquare'

plt.rcParams['font.size'] = 15 # 개별적용 - plt.yticks(fontsize=20)

plt.rcParams['font.weight'] = 'bold'

# 막대그래프 그리기
sns.barplot(grouped['행정동'], grouped['강수일수'],data=tips)

# 그래프 제목, x축 제목, y축 제목 설정
plt.title('행정동별 강수일수',**fontdict)
plt.xticks(rotation=45)
plt.xlabel('행정동명',**fontdict)
plt.ylabel('강수일수',**fontdict)

# 그래프 출력
#plt.show())
plt.savefig('C:\\Users\\seses\\Downloads\\eda_0426\\행정동별강수일수.png',facecolor='#ffffff')
# Out:
# C:\Users\seses\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 행정동별 사고발생 건수

# %%
grouped=grouped.groupby(['행정동'])
grouped=grouped.sum()
grouped=grouped.reset_index()

# %%
grouped=grouped.sort_values('사고 발생 건수', ascending=False)

# %%
#사고건수 상위 다섯개 도로의 사고건수 그래프

plt.figure(figsize=(20, 10))
tips = sns.load_dataset('tips')
sns.set_palette('Dark2')



# legend, title등 font 속성

fontdict={'fontname': 'NanumSquare',
     'fontsize': 25,
     'style': 'oblique', # 'oblique'
      'fontweight': 'bold'}  # 'heavy', 'light', 'ultrabold', 'ultralight'
# x,y axis 폰트 속성 설정

plt.rcParams['font.family'] = 'NanumSquare'

plt.rcParams['font.size'] = 15 # 개별적용 - plt.yticks(fontsize=20)

plt.rcParams['font.weight'] = 'bold'

# 막대그래프 그리기
sns.barplot(grouped['행정동'], grouped['사고 발생 건수'],data=tips)

# 그래프 제목, x축 제목, y축 제목 설정
plt.title('행정동별 사고 발생 건수',**fontdict)
plt.xticks(rotation=45)
plt.xlabel('행정동명',**fontdict)
plt.ylabel('사고 발생 건수',**fontdict)

# 그래프 출력
#plt.show()
plt.savefig('C:\\Users\\seses\\Downloads\\eda_0426\\행정동별사고발생건수.png',facecolor='#ffffff')
# Out:
# C:\Users\seses\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 유동인구추이와 총인구추이 비교 그래프

# %%
df_grouped=df.groupby('행정동')
df_grouped=df_grouped.sum()
df_grouped=df_grouped.reset_index()

# %%
import pandas as pd
import matplotlib.pyplot as plt
#사고건수 상위 다섯개 도로의 사고건수 그래프

plt.figure(figsize=(10, 6))
tips = sns.load_dataset('tips')
sns.set_palette('Dark2')



# legend, title등 font 속성

fontdict={'fontname': 'NanumSquare',
     'fontsize': 20,
     'style': 'oblique', # 'oblique'
      'fontweight': 'bold'}  # 'heavy', 'light', 'ultrabold', 'ultralight'
# x,y axis 폰트 속성 설정

plt.rcParams['font.family'] = 'NanumSquare'

plt.rcParams['font.size'] = 15 # 개별적용 - plt.yticks(fontsize=20)

plt.rcParams['font.weight'] = 'bold'

# 두 개의 선 그래프 그리기
plt.figure(figsize=(20, 6))
sns.lineplot(df_grouped['행정동'], df_grouped['유동인구'],data=tips)
sns.lineplot(df_grouped['행정동'], df_grouped['총인구수'],data=tips)
plt.ticklabel_format(axis='y',useOffset=False, style='plain')
# 그래프 제목, x축 제목, y축 제목 설정
plt.title('행정동별 유동인구와 총인구수 추이',**fontdict)
plt.xticks(rotation=45)
plt.xlabel('행정동',**fontdict)
plt.ylabel('Amount',**fontdict)

# 범례 추가
plt.legend(['유동인구', '총인구수'])

# 그래프 출력
#plt.show()
plt.savefig('C:\\Users\\seses\\Downloads\\eda_0426\\행정동별유동인구와총인구수추이.png',facecolor='#ffffff')
# Out:
# C:\Users\seses\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\seses\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 도로별 사고 건수 상위/하위 5 출력

# %%
import seaborn as sns

# %%
# 특정 열을 기준으로 데이터프레임 정렬
df_grouped = grouped.groupby('도로명').sum()
df_sorted = df_grouped.sort_values('사고 발생 건수', ascending=False)

# 상위 다섯개 값 추출
top5 = df_sorted.head()
top5=top5.reset_index()

# %%
#사고건수 상위 다섯개 도로의 사고건수 그래프

plt.figure(figsize=(10, 6))
tips = sns.load_dataset('tips')
sns.set_palette('Dark2')



# legend, title등 font 속성

fontdict={'fontname': 'NanumSquare',
     'fontsize': 20,
     'style': 'oblique', # 'oblique'
      'fontweight': 'bold'}  # 'heavy', 'light', 'ultrabold', 'ultralight'
# x,y axis 폰트 속성 설정

plt.rcParams['font.family'] = 'NanumSquare'

plt.rcParams['font.size'] = 15 # 개별적용 - plt.yticks(fontsize=20)

plt.rcParams['font.weight'] = 'bold'

# 막대그래프 그리기
sns.barplot(top5['도로명'], top5['사고 발생 건수'],data=tips)

# 그래프 제목, x축 제목, y축 제목 설정
plt.title('Top 5 사고 발생 건수',**fontdict)
plt.xlabel('도로명',**fontdict)
plt.ylabel('사고 발생 건수',**fontdict)

# 그래프 출력
#plt.show()
plt.savefig('C:\\Users\\seses\\Downloads\\eda_0426\\행정동별Top5사고발생건수.png',facecolor='#ffffff')
# Out:
# C:\Users\seses\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# 특정 열을 기준으로 데이터프레임 정렬
df_grouped = grouped.groupby('도로명').sum()
df_sorted_b = df_grouped.sort_values('사고 발생 건수', ascending=True)

# 하위 다섯개 값 추출
bottom5 = df_sorted_b.head()

# %%
bottom5
# Out:
#          도로명      년    월  사고 발생 건수  강수량(mm)   강수일수  안개일수   눈일수  신호기     총인구수  \
# 0     신산로11길  72720  234         1   4997.1  346.0  22.0  33.0    0  1199038
# 1      하도13길  72720  234         1   6860.6  378.0  22.0  33.0    0   558709
# 2  섭지코지로46번길  72720  234         1   6860.6  378.0  57.0  19.0    0   556022
# 3      성굴로2길  72720  234         1   4177.7  351.0  22.0  33.0    0   327686
# 4        성두길  72720  234         1   4997.1  346.0  22.0  33.0    0  1501657
#
#          유동인구
# 0  1791635.77
# 1  1020602.39
# 2  1061738.15
# 3   500455.06
# 4  3202157.26

# %%
bottom5=bottom5.reset_index()

# %% [markdown]
# # 도로별 신호기 개수 평균/상위 5/하위 5/사고발생건수와의 비교

# %%
df_grouped['신호기'].mean()
# Out:
# 18.82920941460471

# %%
# 특정 열을 기준으로 데이터프레임 정렬
df_grouped = grouped.groupby('도로명').sum()
df_sorted_sinho = df_grouped.sort_values('신호기', ascending=False)

# 상위 다섯개 값 추출
#top5 = df_sorted.head()

# %%
# 상위 다섯개 값 추출
top5_sinho = df_sorted_sinho.head()
top5_sinho=top5_sinho.reset_index()

# %%
df_sorted_sinho
# Out:
#              년     월  사고 발생 건수  강수량(mm)    강수일수   안개일수    눈일수   신호기     총인구수  \
# 도로명
# 일주서로    945360  3042       540  68260.1  4549.0  461.0  359.0  6672  9210107
# 일주동로   1090800  3510       646  92059.0  5358.0  680.0  355.0  5700  7651763
# 중산간서로   581760  1872       141  43274.6  2819.0  351.0  194.0  1572  4676757
# 중앙로     799920  2574       562  62163.1  3851.0  417.0  293.0  1416  5633074
# 번영로     509040  1638       208  38706.7  2486.0  189.0  217.0  1260  4603509
# ...        ...   ...       ...      ...     ...    ...    ...   ...      ...
# 삼달하동로    72720   234         1   6860.6   378.0   57.0   19.0     0   556022
# 삼달신풍로    72720   234         1   6860.6   378.0   57.0   19.0     0   556022
# 삼달로      72720   234         4   6860.6   378.0   57.0   19.0     0   556022
# 산천단동길    72720   234         2   4997.1   346.0   22.0   33.0     0  1297325
# 흥운길      72720   234         7   4997.1   346.0   22.0   33.0     0   536855
#
#               유동인구
# 도로명
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
#사고건수 상위 다섯개 도로의 사고건수 그래프

plt.figure(figsize=(10, 6))
tips = sns.load_dataset('tips')
sns.set_palette('Dark2')



# legend, title등 font 속성

fontdict={'fontname': 'NanumSquare',
     'fontsize': 20,
     'style': 'oblique', # 'oblique'
      'fontweight': 'bold'}  # 'heavy', 'light', 'ultrabold', 'ultralight'
# x,y axis 폰트 속성 설정

plt.rcParams['font.family'] = 'NanumSquare'

plt.rcParams['font.size'] = 15 # 개별적용 - plt.yticks(fontsize=20)

plt.rcParams['font.weight'] = 'bold'

# 두 개의 선 그래프 그리기
plt.figure(figsize=(20, 6))
sns.lineplot(df_grouped['행정동'], df_grouped['신호기'],data=tips)
sns.lineplot(df_grouped['행정동'], df_grouped['사고 발생 건수'],data=tips)
plt.ticklabel_format(axis='y',useOffset=False, style='plain')
# 그래프 제목, x축 제목, y축 제목 설정
plt.title('행정동별 신호기와 사고 발생 건수 추이',**fontdict)
plt.xticks(rotation=45)
plt.xlabel('행정동',**fontdict)
plt.ylabel('Amount',**fontdict)

# 범례 추가
plt.legend(['신호기', '사고 발생 건수'])

# 그래프 출력
#plt.show()
plt.savefig('C:\\Users\\seses\\Downloads\\eda_0426\\행정동별신호기와사고발생건수추이.png',facecolor='#ffffff')
# Out:
# C:\Users\seses\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\seses\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#사고건수 상위 다섯개 도로의 사고건수 그래프

plt.figure(figsize=(10, 6))
tips = sns.load_dataset('tips')
sns.set_palette('Dark2')



# legend, title등 font 속성

fontdict={'fontname': 'NanumSquare',
     'fontsize': 20,
     'style': 'oblique', # 'oblique'
      'fontweight': 'bold'}  # 'heavy', 'light', 'ultrabold', 'ultralight'
# x,y axis 폰트 속성 설정

plt.rcParams['font.family'] = 'NanumSquare'

plt.rcParams['font.size'] = 15 # 개별적용 - plt.yticks(fontsize=20)

plt.rcParams['font.weight'] = 'bold'

# 막대그래프 그리기
sns.barplot(top5_sinho['도로명'], top5_sinho['신호기'],data=tips)

# 그래프 제목, x축 제목, y축 제목 설정
plt.title('신호기 개수 Top 5',**fontdict)
plt.xlabel('신호기',**fontdict)
plt.ylabel('사고 발생 건수',**fontdict)

# 그래프 출력
#plt.show()
plt.savefig('C:\\Users\\seses\\Downloads\\eda_0426\\신호기개수Top5.png',facecolor='#ffffff')
# Out:
# C:\Users\seses\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
bottom5_sinho = df_sorted_sinho.tail()

# %%
bottom5_sinho
# Out:
#            년    월  사고 발생 건수  강수량(mm)   강수일수  안개일수   눈일수  신호기     총인구수  \
# 도로명
# 삼달하동로  72720  234         1   6860.6  378.0  57.0  19.0    0   556022
# 삼달신풍로  72720  234         1   6860.6  378.0  57.0  19.0    0   556022
# 삼달로    72720  234         4   6860.6  378.0  57.0  19.0    0   556022
# 산천단동길  72720  234         2   4997.1  346.0  22.0  33.0    0  1297325
# 흥운길    72720  234         7   4997.1  346.0  22.0  33.0    0   536855
#
#              유동인구
# 도로명
# 삼달하동로  1061738.15
# 삼달신풍로  1061738.15
# 삼달로    1061738.15
# 산천단동길  2680780.84
# 흥운길    1097671.08
